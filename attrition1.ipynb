# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
import sklearn

# %%
df1 = pd.read_csv("test.csv")
df= pd.read_csv("train.csv")

# %%
df1.head()
# Out:
#    Id  Age BusinessTravel              Department  DistanceFromHome  \
# 0   1   28  Travel_Rarely  Research & Development                 9
# 1   2   31  Travel_Rarely                   Sales                 6
# 2   3   37  Travel_Rarely  Research & Development                 6
# 3   4   42  Travel_Rarely  Research & Development                 1
# 4   5   45     Non-Travel  Research & Development                 4
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          3        Medical             377                        4    Male
# 1          4        Medical             653                        1    Male
# 2          3        Medical             474                        3    Male
# 3          2  Life Sciences             827                        4  Female
# 4          2  Life Sciences             972                        3    Male
#
#    ...  PerformanceRating StockOptionLevel  TotalWorkingYears  \
# ...

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Id  Age  Attrition BusinessTravel              Department  \
# 0   1   30          0     Non-Travel  Research & Development
# 1   2   36          0  Travel_Rarely  Research & Development
# 2   3   55          1  Travel_Rarely                   Sales
# 3   4   39          0  Travel_Rarely  Research & Development
# 4   5   37          0  Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 2          3        Medical             571
# 1                12          4  Life Sciences            1614
# 2                 2          1        Medical             842
# 3                24          1  Life Sciences            2014
# 4                 3          3          Other             689
#
#    EnvironmentSatisfaction  Gender  JobInvolvement                 JobRole  \
# 0                        3  Female               3   Laboratory Technician
# ...

# %%
df.reset_index()
# Out:
#       index    Id  Age  Attrition     BusinessTravel              Department  \
# 0         0     1   30          0         Non-Travel  Research & Development
# 1         1     2   36          0      Travel_Rarely  Research & Development
# 2         2     3   55          1      Travel_Rarely                   Sales
# 3         3     4   39          0      Travel_Rarely  Research & Development
# 4         4     5   37          0      Travel_Rarely  Research & Development
# ...     ...   ...  ...        ...                ...                     ...
# 1623   1623  1624   42          1  Travel_Frequently  Research & Development
# 1624   1624  1625   55          1      Travel_Rarely                   Sales
# 1625   1625  1626   25          1      Travel_Rarely                   Sales
# 1626   1626  1627   29          1      Travel_Rarely         Human Resources
# 1627   1627  1628   29          1      Travel_Rarely  Research & Development
#
# ...

# %%
p= pd.read_csv("Sample_submission.csv")

# %%
df.columns
# Out:
# Index(['Id', 'Age', 'Attrition', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'CommunicationSkill',
#        'Behaviour'],
#       dtype='object')

# %%
df1.shape
# Out:
# (470, 28)

# %%
df.isnull().sum()
# Out:
# Id                         0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeNumber             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# CommunicationSkill         0
# Behaviour                  0
# dtype: int64

# %%
pd.get_dummies(df, columns=["BusinessTravel"], prefix=["body", "drive"]).head()

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
df["Bussines_travel_new"]=lb_make.fit_transform(df["BusinessTravel"])
df.head()
# Out:
#    Id  Age  Attrition BusinessTravel              Department  \
# 0   1   30          0     Non-Travel  Research & Development
# 1   2   36          0  Travel_Rarely  Research & Development
# 2   3   55          1  Travel_Rarely                   Sales
# 3   4   39          0  Travel_Rarely  Research & Development
# 4   5   37          0  Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 2          3        Medical             571
# 1                12          4  Life Sciences            1614
# 2                 2          1        Medical             842
# 3                24          1  Life Sciences            2014
# 4                 3          3          Other             689
#
#    EnvironmentSatisfaction  Gender  JobInvolvement                 JobRole  \
# 0                        3  Female               3   Laboratory Technician
# ...

# %%
df["Department"].value_counts()
# Out:
# Research & Development    979
# Sales                     568
# Human Resources            81
# Name: Department, dtype: int64

# %%
df["department_new"]=lb_make.fit_transform(df["Department"])
df["EducationField"].value_counts()
# Out:
# Life Sciences       623
# Medical             521
# Marketing           197
# Technical Degree    162
# Other                85
# Human Resources      40
# Name: EducationField, dtype: int64

# %%
df["JobRole_new"]=lb_make.fit_transform(df["JobRole"])
df["JobRole_new"].value_counts()
# Out:
# 7    365
# 6    341
# 2    310
# 8    172
# 4    121
# 0    110
# 3     90
# 1     72
# 5     47
# Name: JobRole_new, dtype: int64

# %%
df["JobRole"].value_counts()
# Out:
# Sales Executive              365
# Research Scientist           341
# Laboratory Technician        310
# Sales Representative         172
# Manufacturing Director       121
# Healthcare Representative    110
# Manager                       90
# Human Resources               72
# Research Director             47
# Name: JobRole, dtype: int64

# %%
df["Gender_new"]=lb_make.fit_transform(df["Gender"])
df["Gender_new"].value_counts()
# Out:
# 1    996
# 0    632
# Name: Gender_new, dtype: int64

# %%
df["EducationField_new"]=lb_make.fit_transform(df["EducationField"])
df["EducationField"].value_counts()
# Out:
# Life Sciences       623
# Medical             521
# Marketing           197
# Technical Degree    162
# Other                85
# Human Resources      40
# Name: EducationField, dtype: int64

# %%
df["MaritalStatus_new"]=lb_make.fit_transform(df["MaritalStatus"])
df["MaritalStatus"].value_counts()
# Out:
# Married     681
# Single      630
# Divorced    317
# Name: MaritalStatus, dtype: int64

# %%
df2= df.drop(['EducationField', 'MaritalStatus','Gender','JobRole','Department','BusinessTravel'], axis = 1) 
df2.head()
# Out:
#    Id  Age  Attrition  DistanceFromHome  Education  EmployeeNumber  \
# 0   1   30          0                 2          3             571
# 1   2   36          0                12          4            1614
# 2   3   55          1                 2          1             842
# 3   4   39          0                24          1            2014
# 4   5   37          0                 3          3             689
#
#    EnvironmentSatisfaction  JobInvolvement  JobSatisfaction  MonthlyIncome  \
# 0                        3               3                4           2564
# 1                        3               3                3           4663
# 2                        3               3                4           5160
# 3                        1               3                4           4108
# 4                        3               3                3           9434
#
#    NumCompaniesWorked OverTime  PercentSalaryHike  PerformanceRating  \
# ...

# %%
df2["Attrition"].value_counts()
# Out:
# 0    843
# 1    785
# Name: Attrition, dtype: int64

# %%
X = df2.iloc[:,4:11]  #independent columns
y = df2["Attrition"]    #target column i.e price range
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(8).plot(kind='barh')
plt.show()
# Out:
# [0.113 0.207 0.102 0.091 0.1   0.245 0.142]

# %%
X = df2.iloc[:,12:21]  #independent columns
y = df2["Attrition"]    #target column i.e price range
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.153 0.027 0.105 0.173 0.123 0.114 0.102 0.101 0.102]

# %%
from feature_selector import FeatureSelector
# Features are in train and labels are in train_labels
fs = FeatureSelector(data = train, labels = train_labels)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-147-03b7508f2e3c> in <module>
# ----> 1 from feature_selector import FeatureSelector
#       2 # Features are in train and labels are in train_labels
#       3 fs = FeatureSelector(data = train, labels = train_labels)
#
# ModuleNotFoundError: No module named 'feature_selector'
